# %% [markdown]
# <a href="https://colab.research.google.com/github/Betsabeh/cancer/blob/master/checking_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
from pathlib import Path
import importlib

# Project directory
project_path = Path("/content/drive/MyDrive/cancer_data")

# Add project directory to Python path
if str(project_path) not in sys.path:
    sys.path.insert(0, str(project_path))

# Refresh Python's import cache
importlib.invalidate_caches()

print("Project path:", project_path)
print("Exists:", project_path.exists())
print("config.py:", (project_path / "config.py").exists())
print("preprocessing.py:", (project_path / "preprocessing.py").exists())
print("tokenizer.py:", (project_path / "tokenizer.py").exists())

print("\nFinding modules:")
print("config:", importlib.util.find_spec("config"))
print("preprocessing:", importlib.util.find_spec("preprocessing"))
print("tokenizer:", importlib.util.find_spec("tokenizer"))

import config
print("config:", config.__file__)

import preprocessing
print("preprocessing:", preprocessing.__file__)

import tokenizer
print("tokenizer:", tokenizer.__file__)

print("All three modules imported successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Project path: /content/drive/MyDrive/cancer_data
# Exists: True
# config.py: True
# preprocessing.py: True
# tokenizer.py: True
#
# Finding modules:
# config: ModuleSpec(name='config', loader=<_frozen_importlib_external.SourceFileLoader object at 0x79ae0365e5d0>, origin='/content/drive/MyDrive/cancer_data/config.py')
# preprocessing: ModuleSpec(name='preprocessing', loader=<_frozen_importlib_external.SourceFileLoader object at 0x79ae0365e3f0>, origin='/content/drive/MyDrive/cancer_data/preprocessing.py')
# tokenizer: ModuleSpec(name='tokenizer', loader=<_frozen_importlib_external.SourceFileLoader object at 0x79ae0365e3f0>, origin='/content/drive/MyDrive/cancer_data/tokenizer.py')
# config: /content/drive/MyDrive/cancer_data/config.py
# preprocessing: /content/drive/MyDrive/cancer_data/preprocessing.py
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
from pathlib import Path
import importlib

from preprocessing import load_expression_data
from config import *

train_x, train_labels = load_expression_data(
    TRAIN_FILE,
    LABEL_COLUMN
)


val_x, val_labels = load_expression_data(
    VAL_FILE,
    LABEL_COLUMN
)


test_x, test_labels = load_expression_data(
    TEST_FILE,
    LABEL_COLUMN
)



print("train shape=",train_x.shape)
print("train labels shape=",train_labels.shape)
print("val shape=",val_x.shape)
print("val labels shape=",val_labels.shape)
print("test shape=",test_x.shape)
print("test labels shape=",test_labels.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# train shape= (7742, 15108)
# train labels shape= (7742,)
# val shape= (1659, 15108)
# val labels shape= (1659,)
# test shape= (1659, 15108)
# test labels shape= (1659,)
